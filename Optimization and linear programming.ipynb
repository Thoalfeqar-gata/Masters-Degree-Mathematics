# %% [markdown]
# # Optimization problems solution

# %% [markdown]
# ## Problem 1
# ![image.png](attachment:image.png)
#
# link: https://www.superprof.co.uk/resources/academic/maths/linear-algebra/linear-programming/linear-programming-problems-and-solutions.html

# %%
from scipy.optimize import linprog
import numpy as np

# %%
c = np.array([30, 40]) #objective function
bounds = [(0, None), (0, None)] #non-negativity constraint
#other constraints
A_ub = np.array([[-40, -30], [-20, -30]]) 
b_ub = np.array([-4000, -3000])

linprog(c, A_ub = A_ub, b_ub = b_ub, bounds = bounds, integrality = 1).x
# Out:
# array([51., 66.])

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = [0.6, 0.5]
A_eq = [[0.3, 0.6], [0.7, 0.4]]
b_eq = [1000, 1500]
bounds = [(0, None), (0, None)]
linprog(c = c, A_eq = A_eq, b_eq = b_eq, bounds = bounds).x
# Out:
# array([1666.66666667,  833.33333333])

# %% [markdown]
# ## Problem 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = [-100_000, -40_000, -18_000]
A_ub = [[0, 1, 0], [-1, -1, 1], [-9, 1, 1], [20, 6, 3]]
b_ub = [10, 0, 0, 182]
bounds = [(0, None), (0, None), (0, None)]
linprog(c = c, A_ub = A_ub, b_ub = b_ub, bounds = bounds).x
# Out:
# array([ 4., 10., 14.])
