# %% [markdown]
# # Optimization problems solution

# %% [markdown]
# ## Problem 1
# ![image.png](attachment:image.png)
#
# link: https://www.superprof.co.uk/resources/academic/maths/linear-algebra/linear-programming/linear-programming-problems-and-solutions.html

# %%
from scipy.optimize import linprog
import numpy as np

# %%
c = [30, 40] #objective function
bounds = [(0, None), (0, None)] #non-negativity constraint
#other constraints
A_eq = [[40, 30], [20, 30]]  
b_eq = [4000, 3000]

linprog(c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, integrality = 1, method = 'simplex').x
# Out:
# /tmp/ipykernel_993/2408599759.py:7: OptimizeWarning: Only `method='highs'` supports integer constraints. Ignoring `integrality`.
#   linprog(c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, integrality = 1, method = 'simplex').x
# /tmp/ipykernel_993/2408599759.py:7: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   linprog(c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, integrality = 1, method = 'simplex').x
# array([50.        , 66.66666667])

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = [-0.6, -0.5]
A_eq = [[0.3, 0.6], [0.7, 0.4]]
b_eq = [1000, 1500]
bounds = [(0, None), (0, None)]
linprog(c = c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, method = 'simplex').x
# Out:
# /tmp/ipykernel_993/4276623451.py:5: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   linprog(c = c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, method = 'simplex').x
# array([1666.66666667,  833.33333333])

# %% [markdown]
# ## Problem 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = [-30, -50]
A_eq = [[1, 1], [1, 3]]
b_eq = [100, 200]
bounds = [(20, None), (10, None)]
linprog(c = c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, method = 'simplex').x
# Out:
# /tmp/ipykernel_993/2197897629.py:5: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   linprog(c = c, A_eq = A_eq, b_eq = b_eq, bounds = bounds, method = 'simplex').x
# array([50., 50.])

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = [-100_000, -40_000, -18_000]
A_ub = [[0, 1, 0], [-1, -1, 1], [-9, 1, 1], [20, 6, 3]]
b_ub = [10, 0, 0, 182]
bounds = [(0, None), (0, None), (0, None)]
linprog(c = c, A_ub = A_ub, b_ub = b_ub, bounds = bounds, method = 'simplex').x
# Out:
# /tmp/ipykernel_993/388190087.py:5: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   linprog(c = c, A_ub = A_ub, b_ub = b_ub, bounds = bounds, method = 'simplex').x
# array([ 4., 10., 14.])
